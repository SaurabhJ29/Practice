# %%
import numpy
import pandas as pd

# %%
d = {'key': ['X','X','Y','Y','Z'],
    'X': numpy.arange(5),
    'Y': [3,4,5,6,7]}

print(d)
# Out:
# {'key': ['X', 'X', 'Y', 'Y', 'Z'], 'X': array([0, 1, 2, 3, 4]), 'Y': [3, 4, 5, 6, 7]}

# %%
df = pd.DataFrame(d)
df
# Out:
#   key  X  Y
# 0   X  0  3
# 1   X  1  4
# 2   Y  2  5
# 3   Y  3  6
# 4   Z  4  7

# %%
df.groupby('key').mean()
# Out:
#        X    Y
# key
# X    0.5  3.5
# Y    2.5  5.5
# Z    4.0  7.0

# %%
# print(df.columns)
# print(df.columns[1])
# Out:
# Index(['key', 'X', 'Y'], dtype='object')
# X

# %%
df[df.columns[0]]
# Out:
# 0    X
# 1    X
# 2    Y
# 3    Y
# 4    Z
# Name: key, dtype: object

# %%
# print(len(df))
# print(len(df.columns))
# Out:
# 5
# 3

# %%
for i in range(0, len(df)):
    print(i+1, df.loc[i, 'key'])
# Out:
# 1 X
# 2 X
# 3 Y
# 4 Y
# 5 Z

# %%
df1 = df['key']
df1
# Out:
# 0    X
# 1    X
# 2    Y
# 3    Y
# 4    Z
# Name: key, dtype: object

# %%
df1 = df.iloc[0 : 2]
df1
# Out:
#   key  X  Y
# 0   X  0  3
# 1   X  1  4

# %%
df1 = df['Y']
df1
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# Name: Y, dtype: int64

# %%
# df = pd.DataFrame(d)
# df.reset_index(drop=True, inplace = True)
# df.set_index('key', inplace=True)
# df
