# %%
# Create New Jupyter Notebook command from the Command Palette (Ctrl+Shift+P) in vscode.
import time

# %%
k = 3

Subs_cr = {'Subject 1': 20, 'Subject 2': 35, 'Subject 3': 30}

print(Subs_cr)
# print(Subs_cr[0])
# print(k)
# Out:
# {'Subject 1': 20, 'Subject 2': 35, 'Subject 3': 30}

# %%
Sub_cr = sorted(Subs_cr.values())
print(Sub_cr)
# Out:
# [20, 30, 35]

# %%
n = 4
Stdnt_Cr_limit = {"Student 1": 40, "Student 2": 50, "Student 3": 30, "Student 4": 80}
Cr_limits = Stdnt_Cr_limit.values()

# %%
print("The number of subjects are: ", k, "\nCredits of these subjects are: ", Subs_cr,
      "\nNumber of students are: ", n, "Credit limits of these students are: ", Stdnt_Cr_limit)
# Out:
# The number of subjects are:  3
# Credits of these subjects are:  {'Subject 1': 20, 'Subject 2': 35, 'Subject 3': 30}
# Number of students are:  4 Credit limits of these students are:  {'Student 1': 40, 'Student 2': 50, 'Student 3': 30, 'Student 4': 80}

# %%
print((Subs_cr.values()))
print((Sub_cr))
# Out:
# dict_values([20, 35, 30])
# [20, 30, 35]

# %%
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

x = list(powerset(Sub_cr))
x.remove(())
print("\nAll the combinations of the subjects credits are: \n",
      x, "\nand the number of elements in it:", len(x))
# Out:
# All the combinations of the subjects credits are:
#  [(20,), (30,), (35,), (20, 30), (20, 35), (30, 35), (20, 30, 35)]
# and the number of elements in it: 7

# %%
total_count = 0

for index, credit_limit in enumerate(Cr_limits):
    count = 0
    print("\n\nThe details of student {} is as follows:".format(index +1))
    
    for index2, j in enumerate(x):
        Cr_sub = 0
        
        if sum(j) <= credit_limit:
            
#            print("\nSubject {} credit is: ".format(index2 + 1) , sum(j))
            count += 1
   #         print("Count: ", count)

    
    print("Student {}, his credit limit is: ".format(index + 1), credit_limit)
        
    total_count += count
    
    print("Total options for the student {} are: ".format(index + 1), count)
        
print("\n\nNumber of ordered pairs are: ", total_count)
# Out:
# The details of student 1 is as follows:
# Student 1, his credit limit is:  40
# Total options for the student 1 are:  3
#
#
# The details of student 2 is as follows:
# Student 2, his credit limit is:  50
# Total options for the student 2 are:  4
#
#
# The details of student 3 is as follows:
# Student 3, his credit limit is:  30
# Total options for the student 3 are:  2
#
#
# The details of student 4 is as follows:
# Student 4, his credit limit is:  80
# Total options for the student 4 are:  6
#
#
# Number of ordered pairs are:  15
