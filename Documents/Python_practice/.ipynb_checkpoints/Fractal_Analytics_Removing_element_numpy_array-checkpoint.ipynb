# %%
#Remove from numpy array
import numpy as np

# %%
list_a = [1,2,3,4,5,6]
list_b = [5,6,7,8,9]
a = np.array(list_a)
b = np.array(list_b)

# print(a, b)
# print(len(a))
# print(len(b))

# %%
# type(list_a[1])

# %%
# type(a[1])

# %%
c = []
for ele in a:
    for element in b:
        if ele==element:
            d = int(ele)
#             print(ele)
            c.append(d)
            
# print(c, d)

removed_array = np.array(c)
print(removed_array)
# Out:
# [5 6]
