# %%
# Create New Jupyter Notebook command from the Command Palette (Ctrl+Shift+P)
def creating_tuple(n):
    t = []
    for i in range(0, n):
        x = int(input("Enter it's value: "))
        t.append(x)
    tpl = tuple(t)
    return tpl

# %%
k = int(input("Enter the no. of Subjects: "))
print("Enter the credits of the {} subjects: " .format(k))
Subs_cr = creating_tuple(k)
# Out:
# Enter the credits of the 3 subjects:

# %%
print(Subs_cr)
print(Subs_cr[0])
print(k)
# Out:
# (25, 20, 30)
# 25
# 3

# %%
n = int(input("Enter the number of the students: "))
print("Enter the credit limit of each {} students" .format(n))
Stdnt_Cr_limit = creating_tuple(n)
# Out:
# Enter the credit limit of each 3 students

# %%
print(k, Subs_cr, n, Stdnt_Cr_limit)
# Out:
# 3 (25, 20, 30) 3 (40, 25, 50)

# %%
print((Subs_cr[1]))
# Out:
# 20

# %%
x = []
for i in Stdnt_Cr_limit:
    y = 0
    # print(i)
    if i>=sum(Subs_cr):
        y = len(Subs_cr)
    # elif i>= Subs_cr:

    else:
        for j in range(k-1, 0, -1):
            if i>=Subs_cr[j]:
                y += 1

    x.append(y)

    

print(tuple(x))
print(sum(tuple(x)))
# Out:
# (2, 1, 2)
# 5

# %%
x = []
for i in Stdnt_Cr_limit:
    y = 0
    # print(i)
    for j in Subs_cr:
        # print(j)
        if i>=j:
            y = y+1
        # elif i<=j:
    x.append(y)

print(tuple(x))
print(sum(tuple))
# Out:
# (3, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\saura\Documents\Python_practice\Practice_1.ipynb Cell 8' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/saura/Documents/Python_practice/Practice_1.ipynb#ch0000007?line=9'>10</a>     x.append(y)
#      <a href='vscode-notebook-cell:/c%3A/Users/saura/Documents/Python_practice/Practice_1.ipynb#ch0000007?line=11'>12</a> print(tuple(x))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/saura/Documents/Python_practice/Practice_1.ipynb#ch0000007?line=12'>13</a> print(sum(tuple))
#
# TypeError: 'type' object is not iterable

# %%
def maxcredit(input1, input2, input3, input4):
    result=0
    for i in input2:
        if i <= input4[input3-1]:
            result +=1
    return result

print(maxcredit (3,[48],1,[28,32,63]))
# Out:
# 0
