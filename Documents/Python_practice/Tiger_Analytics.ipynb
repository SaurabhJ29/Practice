# %%
class A:
    def __init__(s):
        self.s = s
        
    def print():
        pass
    
a = A('John')
a.print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10600/1357681080.py in <module>
#       6         pass
#       7
# ----> 8 a = A('John')
#       9 a.print()
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
class A:
    def __init__(self, s):
        self.s = s
        
    def print(self):
        print(self.s)
        pass
    
a = A('John')
a.print()
# Out:
# John

# %%
def add(a,b):
    assert(a>b)
    assert(a<b)
    print(a/b)
    
add(4,0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10600/3457940540.py in <module>
#       4     print(a/b)
#       5
# ----> 6 add(4,0)
#
# ~\AppData\Local\Temp/ipykernel_10600/3457940540.py in add(a, b)
#       1 def add(a,b):
#       2     assert(a>b)
# ----> 3     assert(a<b)
#       4     print(a/b)
#       5
#
# AssertionError:

# %%
def add(a,b):
#     assert(a>b)
    assert(b>a)
    print(a/b)
    
add(4,0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10600/1817766298.py in <module>
#       4     print(a/b)
#       5
# ----> 6 add(4,0)
#
# ~\AppData\Local\Temp/ipykernel_10600/1817766298.py in add(a, b)
#       1 def add(a,b):
#       2 #     assert(a>b)
# ----> 3     assert(b>a)
#       4     print(a/b)
#       5
#
# AssertionError:
